# %%
# !pwd
# Out:
# /content

# %%
import os
os.chdir('/content/drive/My Drive/ANPR/darknet')

# %%
# !./darknet
# Out:
# /bin/bash: ./darknet: Permission denied

# %%
# !sudo chmod +x ./darknet

# %%
# !./darknet
# Out:
# usage: ./darknet <function>

# %%
# !./darknet detector train data/numberPlateData/image_data.data cfg/yolov4_train.cfg yolov4.conv.137 -dont_show
# Out:
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.872727), count: 2, class_loss = 0.511347, iou_loss = 12.165309, total_loss = 12.676656
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.762154), count: 12, class_loss = 3.093049, iou_loss = 19.952675, total_loss = 23.045723
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.754246), count: 15, class_loss = 2.487316, iou_loss = 3.182267, total_loss = 5.669583
#  total_bbox = 318363, rewritten_bbox = 0.001571 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000367, iou_loss = 0.000000, total_loss = 0.000367
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000281, iou_loss = 0.000000, total_loss = 0.000281
# ...

# %%
# !./darknet detector train data/numberPlateData/image_data.data cfg/yolov4_train.cfg backup/yolov4_train_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  1836: 0.385857, 0.394374 avg loss, 0.000013 rate, 5.158670 seconds, 58752 images, 0.471719 hours left
# Loaded: 0.000054 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.159082, iou_loss = 0.000000, total_loss = 0.159082
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.917890), count: 5, class_loss = 0.126546, iou_loss = 4.488870, total_loss = 4.615416
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.892989), count: 9, class_loss = 0.156763, iou_loss = 6.219315, total_loss = 6.376079
#  total_bbox = 132254, rewritten_bbox = 0.000756 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000054, iou_loss = 0.000000, total_loss = 0.000054
# ...

# %%
# !./darknet detector train data/numberPlateData/image_data.data cfg/yolov4_train.cfg backup/yolov4_train_last.weights -dont_show
# Out:
#  CUDA-version: 10010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov4_train
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 2, batch = 32, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %%
# !./darknet detector test data/numberPlateData/image_data.data cfg/yolov4_train.cfg backup/yolov4_train_final.weights test.jpeg -thresh 0.3
# Out:
#  CUDA-version: 10010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...
